# %% [markdown]
# Jun0523: This is a continuous, 47-minute file featuring stims. at minutes 5, 12, 19, 26, 33, and 40; the corresponding time steps would be 122175, 293220, 464265, 635310, 806355, and 977400. Note that all of the applied stimuli were identical except the one applied at 33 minutes: I ramped up the intensity of this stimulus to study the effects of perturbing the population and then reduced it back to baseline for the stimulus at 40 minutes.

# %%
''' 
import h5py

file_path = 'Jun0523_1_peaks.mat'

with h5py.File(file_path, 'r') as f:
    # List all variables in the MAT file
    print(list(f.keys()))

    # Example: access a variable called 'peaks'
    peaks = f['peaks'][:]
    print(peaks.shape)
'''
# Out:
# " \nimport h5py\n\nfile_path = 'Jun0523_1_peaks.mat'\n\nwith h5py.File(file_path, 'r') as f:\n    # List all variables in the MAT file\n    print(list(f.keys()))\n\n    # Example: access a variable called 'peaks'\n    peaks = f['peaks'][:]\n    print(peaks.shape)\n"

# %%
'''
## Save peaks as npy file
import numpy as np
np.save('Jun0523_peaks.npy', peaks)
'''
# Out:
# "\n## Save peaks as npy file\nimport numpy as np\nnp.save('Jun0523_peaks.npy', peaks)\n"

# %%
## Import peaks from npy file
import numpy as np
peaks = np.load('../data/sea_slug/Jun0523_peaks.npy')

# %%
import sys
sys.getsizeof(peaks)

# %%
peaks.shape

# %%
import numpy as np
def count_zeros_ones(series, n_bins):
    """
    Count the number of 0s and 1s in each bin of a 0/1 series.

    Parameters
    ----------
    series : array-like
        1D array or list of 0s and 1s.
    n_bins : int
        Number of bins to split the series into.

    Returns
    -------
    counts_0 : np.ndarray
        Array of counts of 0s per bin.
    counts_1 : np.ndarray
        Array of counts of 1s per bin.
    """
    ## Initial parameters
    series = np.asarray(series)
    bin_edges = np.linspace(0, len(series), n_bins + 1, dtype=int)
    counts_0 = np.zeros(n_bins, dtype=int)
    counts_1 = np.zeros(n_bins, dtype=int)
    ## Obtain the bins and counts per bin
    for i in range(n_bins):
        start = bin_edges[i]
        end = bin_edges[i + 1]
        bin_data = series[start:end]
        counts_0[i] = np.sum(bin_data == 0)
        counts_1[i] = np.sum(bin_data == 1)
    ## Return counts
    return counts_0, counts_1

# %%
peaks_vince = np.loadtxt('../data/sea_slug/Jun0523_lyzinski.csv', delimiter=',', dtype=object, skiprows=1)[:,2:].astype(float)

# %%
n_bins = 47
n_nodes = peaks.shape[1]
counts_peaks = np.zeros((n_nodes, n_bins), dtype=int)
for i in range(n_nodes):
    counts_peaks[i] = count_zeros_ones(peaks[:,i], n_bins)[1]

# %%
import matplotlib.pyplot as plt
## Compile with tikz and times font
plt.rc('text', usetex=True)
plt.rc('font', family='times')

# %%
plt.figure(figsize=(5, 3))
plt.plot(counts_peaks.T, color='gray', alpha=0.25, lw=0.5)
plt.plot(counts_peaks.mean(axis=0), color='black', lw=1.5, label='Mean')
plt.plot(np.median(counts_peaks,axis=0), color='blue', lw=1.5, label='Median', ls='dotted')
plt.xlabel('Time (in minutes)')
plt.ylabel('Number of peaks')
for j, p in enumerate([5, 12, 19, 26, 33, 40]):
    if j == 0:
        plt.axvline(x=p, ls='dashed', c='DarkRed', label='Stimulus', lw=1.0)
    else:
        plt.axvline(x=p, ls='dashed', c='DarkRed', lw=1.0)
plt.legend()
plt.savefig('../figures/peaks_Jun0523.pdf', bbox_inches='tight')
plt.show()

# %%
plt.plot(np.log(counts_peaks.T+1), color='gray', alpha=0.25, lw=0.5)
plt.plot(np.log(counts_peaks.mean(axis=0)+1), color='black', lw=2, label='Mean')
plt.plot(np.median(np.log(counts_peaks+1), axis=0), color='blue', lw=2, label='Median', ls='dotted')
plt.xlabel('Time')
plt.ylabel('Number of peaks in time bin (log+1 scale)')
plt.legend()
plt.savefig('../figures/peaks_log_scale_Jun0523.pdf', bbox_inches='tight')
plt.show()

# %%
plt.plot(peaks_vince.T, color='gray', alpha=0.75, lw=0.5)
plt.plot(peaks_vince.mean(axis=0), color='black', lw=2, label='Mean')
plt.xlabel('Time')
plt.ylabel('Normalised degree correction')
plt.savefig('../figures/degree_correction_Jun0523.pdf', bbox_inches='tight')
plt.show()

# %%
plt.plot(np.log(peaks_vince.T+1), color='gray', alpha=0.75, lw=0.5)
plt.plot(np.log(peaks_vince.mean(axis=0)+1), color='black', lw=2, label='Mean')
plt.xlabel('Time')
plt.ylabel('Normalised degree correction (log+1 scale)')
plt.savefig('../figures/degree_correction_log_scale_Jun0523.pdf', bbox_inches='tight')
plt.show()
